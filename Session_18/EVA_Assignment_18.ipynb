# %% [markdown]
# <a href="https://colab.research.google.com/github/hardayal/EVA/blob/master/Session_18/EVA_Assignment_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>

# %%
from google.colab import files
uploaded = files.upload()
# !ls
# Out:
#      <input type="file" id="files-c58f14a2-da85-4e6f-b690-2db74b5e5feb" name="files[]" multiple disabled />
#      <output id="result-c58f14a2-da85-4e6f-b690-2db74b5e5feb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving generate_cifar10_tfrecords.py to generate_cifar10_tfrecords.py
# generate_cifar10_tfrecords.py  sample_data

# %%
# !ls
# Out:
# generate_cifar10_tfrecords.py  sample_data

# %%
# !python generate_cifar10_tfrecords.py
# Out:
# Download from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz and extract.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From generate_cifar10_tfrecords.py:42: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/learn/python/learn/datasets/base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded cifar-10-python.tar.gz 170498071 bytes.
# Generating train.tfrecords
# WARNING:tensorflow:From generate_cifar10_tfrecords.py:76: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# WARNING:tensorflow:From generate_cifar10_tfrecords.py:65: The name tf.gfile.Open is deprecated. Please use tf.io.gfile.GFile instead.
#
# Generating validation.tfrecords
# Generating eval.tfrecords
# Done!

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time, math

tf.enable_eager_execution()

filename_train = 'train.tfrecords' 
filename_test = 'validation.tfrecords' 
HEIGHT = 32
WIDTH = 32
DEPTH = 3
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
def normalize(image):
  """Convert `image` from [0, 255] -> [0, 1] floats."""
  image = tf.cast(image, tf.float32) * (1. / 255)
  return image  

def preprocess(image):
    """Preprocess a single image in [height, width, depth] layout."""
    # Pad 4 pixels on each dimension of feature map, done in mini-batch
    image = tf.image.resize_image_with_crop_or_pad(image, 40, 40)
    image = tf.random_crop(image, [HEIGHT, WIDTH, DEPTH])
    image = tf.image.random_flip_left_right(image)
    return image
def replace_slice(input_: tf.Tensor, replacement, begin) -> tf.Tensor:
    inp_shape = tf.shape(input_)
    size = tf.shape(replacement)
    padding = tf.stack([begin, inp_shape - (begin + size)], axis=1)
    replacement_pad = tf.pad(replacement, padding)
    mask = tf.pad(tf.ones_like(replacement, dtype=tf.bool), padding)
    return tf.where(mask, replacement_pad, input_)
def cutout(x: tf.Tensor, h: int=8, w: int=8, c: int = 3) -> tf.Tensor:
    shape = tf.shape(x)
    x0 = tf.random.uniform([], 0, shape[0] + 1 - h, dtype=tf.int32)
    y0 = tf.random.uniform([], 0, shape[1] + 1 - w, dtype=tf.int32)
    
    x = replace_slice(x, tf.random.uniform([h, w, c], dtype = tf.float32), [x0, y0, 0])
#     x = replace_slice(x, tf.zeros([h, w, c], dtype = tf.float32), [x0, y0, 0])
    return x

# %%
def parser(serialized_example):
    """Parses a single tf.Example into image and label tensors."""
    # Dimensions of the images in the CIFAR-10 dataset.
    # See http://www.cs.toronto.edu/~kriz/cifar.html for a description of the
    # input format.
    features = tf.parse_single_example(
        serialized_example,
        features={
            'image': tf.FixedLenFeature([], tf.string),
            'label': tf.FixedLenFeature([], tf.int64),
        })
    image = tf.decode_raw(features['image'], tf.uint8)
    image.set_shape([DEPTH * HEIGHT * WIDTH])
    image = normalize(image)

    # Reshape from [depth * height * width] to [depth, height, width].
    image = tf.cast(
        tf.transpose(tf.reshape(image, [DEPTH, HEIGHT, WIDTH]), [1, 2, 0]),
        tf.float32)
    label = tf.cast(features['label'], tf.int32)
    label = tf.one_hot(label, 10)

    # Custom preprocessing.
    image = preprocess(image)
    image = cutout(image)

    return image, label  
  
def parser_test(serialized_example):
    """Parses a single tf.Example into image and label tensors."""
    # Dimensions of the images in the CIFAR-10 dataset.
    # See http://www.cs.toronto.edu/~kriz/cifar.html for a description of the
    # input format.
    features = tf.parse_single_example(
        serialized_example,
        features={
            'image': tf.FixedLenFeature([], tf.string),
            'label': tf.FixedLenFeature([], tf.int64),
        })
    image = tf.decode_raw(features['image'], tf.uint8)
    image.set_shape([DEPTH * HEIGHT * WIDTH])
    image = normalize(image)

    # Reshape from [depth * height * width] to [depth, height, width].
    image = tf.cast(
        tf.transpose(tf.reshape(image, [DEPTH, HEIGHT, WIDTH]), [1, 2, 0]),
        tf.float32)
    label = tf.cast(features['label'], tf.int32)
    label = tf.one_hot(label, 10)

    return image, label

# %%
# Hyperparameters
num_classes = 10
dropout_rate = 0.1
batch_size = 512
num_epochs = 200

# %%
# -----------TRAIN TFRecords
# dataset_train = dataset_train.batch(batch_size)
# iterator = dataset_train.make_one_shot_iterator()
# image_batch, label_batch = iterator.get_next()

# -------------TEST TFRecords
dataset_test = tf.data.TFRecordDataset(filename_test).repeat(1)
# dataset_test = dataset_test.apply(tf.contrib.data.shuffle_and_repeat(1,10000))
# dataset_test = dataset_test.apply(tf.contrib.data.map_and_batch(parser,batch_size))

dataset_test = dataset_test.map(parser_test, num_parallel_calls=batch_size)
dataset_test = dataset_test.shuffle(buffer_size=10000) 

# Batch it up.
dataset_test = dataset_test.batch(batch_size)
# iterator = dataset_train.make_one_shot_iterator()
# image_batch, label_batch = iterator.get_next()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.parse_single_example is deprecated. Please use tf.io.parse_single_example instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.FixedLenFeature is deprecated. Please use tf.io.FixedLenFeature instead.

# %%
import tensorflow as tf

def _stage(tensor, nb_groups, in_channels, out_channels, repeat):
    x = _shufflenet_unit(tensor, nb_groups, in_channels, out_channels, 2)

    for _ in range(repeat):
        x = _shufflenet_unit(x, nb_groups, out_channels, out_channels, 1)

    return x


def _pw_group(tensor, nb_groups, in_channels, out_channels):
    """Pointwise grouped convolution."""
    nb_chan_per_grp = in_channels // nb_groups

    pw_convs = []
    for grp in range(nb_groups):
        x = tf.keras.layers.Lambda(lambda x: x[:, :, :, nb_chan_per_grp * grp: nb_chan_per_grp * (grp + 1)])(tensor)
        grp_out_chan = int(out_channels / nb_groups + 0.5)

        pw_convs.append(
            tf.keras.layers.Conv2D(grp_out_chan,
                   kernel_size=(1, 1),
                   padding='same',
                   use_bias=False,
                   strides=1)(x)
        )

    return tf.keras.layers.Concatenate(axis=-1)(pw_convs)


def _shuffle(x, nb_groups):
    def shuffle_layer(x):
        _, w, h, n = tf.keras.backend.int_shape(x)
        nb_chan_per_grp = n // nb_groups

        x = tf.reshape(x, (-1, w, h, nb_chan_per_grp, nb_groups))
        x = tf.keras.backend.permute_dimensions(x, (0, 1, 2, 4, 3)) # Transpose only grps and chs
        x = tf.reshape(x, (-1, w, h, n))

        return x

    return tf.keras.layers.Lambda(shuffle_layer)(x)


def _shufflenet_unit(tensor, nb_groups, in_channels, out_channels, strides, shuffle=True, bottleneck=8):
    bottleneck_channels = out_channels // bottleneck

    x = _pw_group(tensor, nb_groups, in_channels, bottleneck_channels)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)

    if shuffle:
        x = _shuffle(x, nb_groups)

    x = tf.keras.layers.DepthwiseConv2D(kernel_size=(3, 3),
                        padding='same',
                        use_bias=False,
                        strides=strides)(x)
    x = tf.keras.layers.BatchNormalization()(x)


    x = _pw_group(x, nb_groups, bottleneck_channels,
                  out_channels if strides < 2 else out_channels - in_channels)
    x = tf.keras.layers.BatchNormalization()(x)

    if strides < 2:
        x = tf.keras.layers.Add()([tensor, x])
    else:
        avg = tf.keras.layers.AveragePooling2D(pool_size=(3, 3),
                               strides=2,
                               padding='same')(tensor)

        x = tf.keras.layers.Concatenate(axis=-1)([avg, x])

    x = tf.keras.layers.Activation('relu')(x)

    return x


def _info(nb_groups):
    return {
        1: [24, 144, 288, 576],
        2: [24, 200, 400, 800],
        3: [24, 240, 480, 960],
        4: [24, 272, 544, 1088],
        8: [24, 384, 768, 1536]
    }[nb_groups], [None, 3, 7, 3]


def ShuffleNet(input_shape, nb_classes, include_top=True, weights=None, nb_groups=3):
    x_in = tf.keras.Input(shape=input_shape)

    x = tf.keras.layers.Conv2D(24,
               kernel_size=(3, 3),
               strides=1,
               use_bias=False,
               padding='same')(x_in)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)

    channels_list, repeat_list = _info(nb_groups)
    for i, (out_channels, repeat) in enumerate(zip(channels_list[1:], repeat_list[1:]), start=1):
        x = _stage(x, nb_groups, channels_list[i-1], out_channels, repeat)

    if include_top:
        x = tf.keras.layers.GlobalAveragePooling2D()(x)
        x = tf.keras.layers.Dense(nb_classes, activation='softmax')(x)

    model = tf.keras.Model(inputs=x_in, outputs=x)

    if weights is not None:
        model.load_weights(weights, by_name=True)

    return model

# %%
model = ShuffleNet((32,32,3),10)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 24)   648         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 24)   96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 24)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 32, 32, 8)    0           activation[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 32, 32, 8)    0           activation[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 32, 32, 8)    0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 10)   80          lambda[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 10)   80          lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 10)   80          lambda_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 30)   0           conv2d_1[0][0]
#                                                                  conv2d_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 30)   120         concatenate[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 30)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 32, 32, 30)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d (DepthwiseConv (None, 16, 16, 30)   270         lambda_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 16, 16, 30)   120         depthwise_conv2d[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 16, 16, 10)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 16, 16, 10)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 16, 16, 10)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 72)   720         lambda_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 72)   720         lambda_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 72)   720         lambda_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 216)  0           conv2d_4[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 16, 16, 24)   0           activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 216)  864         concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 16, 16, 240)  0           average_pooling2d[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 16, 16, 240)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 16, 16, 80)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 16, 16, 80)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 16, 16, 80)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 10)   800         lambda_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 10)   800         lambda_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 10)   800         lambda_9[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 16, 30)   0           conv2d_7[0][0]
#                                                                  conv2d_8[0][0]
#                                                                  conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 30)   120         concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 16, 16, 30)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 16, 16, 30)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_1 (DepthwiseCo (None, 16, 16, 30)   270         lambda_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 30)   120         depthwise_conv2d_1[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 16, 16, 10)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 16, 16, 10)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 16, 16, 10)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 80)   800         lambda_11[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 80)   800         lambda_12[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 80)   800         lambda_13[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 16, 16, 240)  0           conv2d_10[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 240)  960         concatenate_4[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 16, 16, 240)  0           activation_2[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 16, 16, 240)  0           add[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 16, 16, 80)   0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 16, 16, 80)   0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 16, 16, 80)   0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 10)   800         lambda_14[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 10)   800         lambda_15[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 10)   800         lambda_16[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 16, 16, 30)   0           conv2d_13[0][0]
#                                                                  conv2d_14[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 30)   120         concatenate_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 16, 16, 30)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 16, 16, 30)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2 (DepthwiseCo (None, 16, 16, 30)   270         lambda_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 30)   120         depthwise_conv2d_2[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 16, 16, 10)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 16, 16, 10)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 16, 16, 10)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 80)   800         lambda_18[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 80)   800         lambda_19[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 16, 16, 80)   800         lambda_20[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 16, 16, 240)  0           conv2d_16[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 240)  960         concatenate_6[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 16, 16, 240)  0           activation_4[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 16, 240)  0           add_1[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 16, 16, 80)   0           activation_6[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 16, 16, 80)   0           activation_6[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 16, 16, 80)   0           activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 16, 16, 10)   800         lambda_21[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 16, 16, 10)   800         lambda_22[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 16, 16, 10)   800         lambda_23[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 16, 16, 30)   0           conv2d_19[0][0]
#                                                                  conv2d_20[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 30)   120         concatenate_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 30)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (None, 16, 16, 30)   0           activation_7[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_3 (DepthwiseCo (None, 16, 16, 30)   270         lambda_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 30)   120         depthwise_conv2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_25 (Lambda)              (None, 16, 16, 10)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# lambda_26 (Lambda)              (None, 16, 16, 10)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 16, 16, 10)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 16, 16, 80)   800         lambda_25[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 16, 16, 80)   800         lambda_26[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 16, 16, 80)   800         lambda_27[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 16, 16, 240)  0           conv2d_22[0][0]
#                                                                  conv2d_23[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 240)  960         concatenate_8[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 16, 16, 240)  0           activation_6[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 240)  0           add_2[0][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, 16, 16, 80)   0           activation_8[0][0]
# __________________________________________________________________________________________________
# lambda_29 (Lambda)              (None, 16, 16, 80)   0           activation_8[0][0]
# __________________________________________________________________________________________________
# lambda_30 (Lambda)              (None, 16, 16, 80)   0           activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 16, 16, 20)   1600        lambda_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 16, 16, 20)   1600        lambda_29[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 16, 16, 20)   1600        lambda_30[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 16, 16, 60)   0           conv2d_25[0][0]
#                                                                  conv2d_26[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 60)   240         concatenate_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 60)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (None, 16, 16, 60)   0           activation_9[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_4 (DepthwiseCo (None, 8, 8, 60)     540         lambda_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 60)     240         depthwise_conv2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              (None, 8, 8, 20)     0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# lambda_33 (Lambda)              (None, 8, 8, 20)     0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# lambda_34 (Lambda)              (None, 8, 8, 20)     0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 8, 8, 80)     1600        lambda_32[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 8, 8, 80)     1600        lambda_33[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 8, 8, 80)     1600        lambda_34[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 8, 8, 240)    0           conv2d_28[0][0]
#                                                                  conv2d_29[0][0]
#                                                                  conv2d_30[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 8, 8, 240)    0           activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 8, 240)    960         concatenate_10[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 8, 8, 480)    0           average_pooling2d_1[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 8, 8, 480)    0           concatenate_11[0][0]
# __________________________________________________________________________________________________
# lambda_35 (Lambda)              (None, 8, 8, 160)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_36 (Lambda)              (None, 8, 8, 160)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_37 (Lambda)              (None, 8, 8, 160)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 8, 8, 20)     3200        lambda_35[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 8, 8, 20)     3200        lambda_36[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 8, 8, 20)     3200        lambda_37[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 8, 8, 60)     0           conv2d_31[0][0]
#                                                                  conv2d_32[0][0]
#                                                                  conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 8, 60)     240         concatenate_12[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 8, 60)     0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# lambda_38 (Lambda)              (None, 8, 8, 60)     0           activation_11[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_5 (DepthwiseCo (None, 8, 8, 60)     540         lambda_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 8, 8, 60)     240         depthwise_conv2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_39 (Lambda)              (None, 8, 8, 20)     0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# lambda_40 (Lambda)              (None, 8, 8, 20)     0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# lambda_41 (Lambda)              (None, 8, 8, 20)     0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 8, 8, 160)    3200        lambda_39[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 8, 8, 160)    3200        lambda_40[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 8, 8, 160)    3200        lambda_41[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 8, 8, 480)    0           conv2d_34[0][0]
#                                                                  conv2d_35[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 8, 8, 480)    1920        concatenate_13[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 8, 8, 480)    0           activation_10[0][0]
#                                                                  batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 8, 8, 480)    0           add_3[0][0]
# __________________________________________________________________________________________________
# lambda_42 (Lambda)              (None, 8, 8, 160)    0           activation_12[0][0]
# __________________________________________________________________________________________________
# lambda_43 (Lambda)              (None, 8, 8, 160)    0           activation_12[0][0]
# __________________________________________________________________________________________________
# lambda_44 (Lambda)              (None, 8, 8, 160)    0           activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 8, 8, 20)     3200        lambda_42[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 8, 8, 20)     3200        lambda_43[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 8, 8, 20)     3200        lambda_44[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 8, 8, 60)     0           conv2d_37[0][0]
#                                                                  conv2d_38[0][0]
#                                                                  conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 8, 8, 60)     240         concatenate_14[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8, 8, 60)     0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# lambda_45 (Lambda)              (None, 8, 8, 60)     0           activation_13[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_6 (DepthwiseCo (None, 8, 8, 60)     540         lambda_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 8, 8, 60)     240         depthwise_conv2d_6[0][0]
# __________________________________________________________________________________________________
# lambda_46 (Lambda)              (None, 8, 8, 20)     0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# lambda_47 (Lambda)              (None, 8, 8, 20)     0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# lambda_48 (Lambda)              (None, 8, 8, 20)     0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 8, 8, 160)    3200        lambda_46[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 8, 8, 160)    3200        lambda_47[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 8, 8, 160)    3200        lambda_48[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 8, 8, 480)    0           conv2d_40[0][0]
#                                                                  conv2d_41[0][0]
#                                                                  conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 8, 8, 480)    1920        concatenate_15[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 8, 8, 480)    0           activation_12[0][0]
#                                                                  batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 480)    0           add_4[0][0]
# __________________________________________________________________________________________________
# lambda_49 (Lambda)              (None, 8, 8, 160)    0           activation_14[0][0]
# __________________________________________________________________________________________________
# lambda_50 (Lambda)              (None, 8, 8, 160)    0           activation_14[0][0]
# __________________________________________________________________________________________________
# lambda_51 (Lambda)              (None, 8, 8, 160)    0           activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 8, 8, 20)     3200        lambda_49[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 8, 8, 20)     3200        lambda_50[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 8, 8, 20)     3200        lambda_51[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 8, 8, 60)     0           conv2d_43[0][0]
#                                                                  conv2d_44[0][0]
#                                                                  conv2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 8, 8, 60)     240         concatenate_16[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 8, 60)     0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# lambda_52 (Lambda)              (None, 8, 8, 60)     0           activation_15[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_7 (DepthwiseCo (None, 8, 8, 60)     540         lambda_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 8, 8, 60)     240         depthwise_conv2d_7[0][0]
# __________________________________________________________________________________________________
# lambda_53 (Lambda)              (None, 8, 8, 20)     0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# lambda_54 (Lambda)              (None, 8, 8, 20)     0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# lambda_55 (Lambda)              (None, 8, 8, 20)     0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 8, 8, 160)    3200        lambda_53[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 8, 8, 160)    3200        lambda_54[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 8, 8, 160)    3200        lambda_55[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 8, 8, 480)    0           conv2d_46[0][0]
#                                                                  conv2d_47[0][0]
#                                                                  conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 8, 8, 480)    1920        concatenate_17[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 480)    0           activation_14[0][0]
#                                                                  batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 8, 480)    0           add_5[0][0]
# __________________________________________________________________________________________________
# lambda_56 (Lambda)              (None, 8, 8, 160)    0           activation_16[0][0]
# __________________________________________________________________________________________________
# lambda_57 (Lambda)              (None, 8, 8, 160)    0           activation_16[0][0]
# __________________________________________________________________________________________________
# lambda_58 (Lambda)              (None, 8, 8, 160)    0           activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 8, 8, 20)     3200        lambda_56[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 8, 8, 20)     3200        lambda_57[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 8, 8, 20)     3200        lambda_58[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 8, 8, 60)     0           conv2d_49[0][0]
#                                                                  conv2d_50[0][0]
#                                                                  conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 8, 8, 60)     240         concatenate_18[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 8, 8, 60)     0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# lambda_59 (Lambda)              (None, 8, 8, 60)     0           activation_17[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_8 (DepthwiseCo (None, 8, 8, 60)     540         lambda_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 8, 8, 60)     240         depthwise_conv2d_8[0][0]
# __________________________________________________________________________________________________
# lambda_60 (Lambda)              (None, 8, 8, 20)     0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# lambda_61 (Lambda)              (None, 8, 8, 20)     0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# lambda_62 (Lambda)              (None, 8, 8, 20)     0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 8, 8, 160)    3200        lambda_60[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 8, 8, 160)    3200        lambda_61[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 8, 8, 160)    3200        lambda_62[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 8, 8, 480)    0           conv2d_52[0][0]
#                                                                  conv2d_53[0][0]
#                                                                  conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 8, 8, 480)    1920        concatenate_19[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 480)    0           activation_16[0][0]
#                                                                  batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 8, 8, 480)    0           add_6[0][0]
# __________________________________________________________________________________________________
# lambda_63 (Lambda)              (None, 8, 8, 160)    0           activation_18[0][0]
# __________________________________________________________________________________________________
# lambda_64 (Lambda)              (None, 8, 8, 160)    0           activation_18[0][0]
# __________________________________________________________________________________________________
# lambda_65 (Lambda)              (None, 8, 8, 160)    0           activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 8, 8, 20)     3200        lambda_63[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 8, 8, 20)     3200        lambda_64[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 8, 8, 20)     3200        lambda_65[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 8, 8, 60)     0           conv2d_55[0][0]
#                                                                  conv2d_56[0][0]
#                                                                  conv2d_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 8, 8, 60)     240         concatenate_20[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 8, 8, 60)     0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# lambda_66 (Lambda)              (None, 8, 8, 60)     0           activation_19[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_9 (DepthwiseCo (None, 8, 8, 60)     540         lambda_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 8, 8, 60)     240         depthwise_conv2d_9[0][0]
# __________________________________________________________________________________________________
# lambda_67 (Lambda)              (None, 8, 8, 20)     0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 4, 4, 480)    1920        concatenate_27[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 4, 4, 960)    0           average_pooling2d_2[0][0]
#                                                                  batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 4, 4, 960)    0           concatenate_28[0][0]
# __________________________________________________________________________________________________
# lambda_91 (Lambda)              (None, 4, 4, 320)    0           activation_26[0][0]
# __________________________________________________________________________________________________
# lambda_92 (Lambda)              (None, 4, 4, 320)    0           activation_26[0][0]
# __________________________________________________________________________________________________
# lambda_93 (Lambda)              (None, 4, 4, 320)    0           activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 4, 4, 40)     12800       lambda_91[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 4, 4, 40)     12800       lambda_92[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 4, 4, 40)     12800       lambda_93[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 4, 4, 120)    0           conv2d_79[0][0]
#                                                                  conv2d_80[0][0]
#                                                                  conv2d_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 4, 4, 120)    480         concatenate_29[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 4, 4, 120)    0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# lambda_94 (Lambda)              (None, 4, 4, 120)    0           activation_27[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_13 (DepthwiseC (None, 4, 4, 120)    1080        lambda_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 4, 4, 120)    480         depthwise_conv2d_13[0][0]
# __________________________________________________________________________________________________
# lambda_95 (Lambda)              (None, 4, 4, 40)     0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# lambda_96 (Lambda)              (None, 4, 4, 40)     0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# lambda_97 (Lambda)              (None, 4, 4, 40)     0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 4, 4, 320)    12800       lambda_95[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 4, 4, 320)    12800       lambda_96[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 4, 4, 320)    12800       lambda_97[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 4, 4, 960)    0           conv2d_82[0][0]
#                                                                  conv2d_83[0][0]
#                                                                  conv2d_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 4, 4, 960)    3840        concatenate_30[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 4, 4, 960)    0           activation_26[0][0]
#                                                                  batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 4, 4, 960)    0           add_10[0][0]
# __________________________________________________________________________________________________
# lambda_98 (Lambda)              (None, 4, 4, 320)    0           activation_28[0][0]
# __________________________________________________________________________________________________
# lambda_99 (Lambda)              (None, 4, 4, 320)    0           activation_28[0][0]
# __________________________________________________________________________________________________
# lambda_100 (Lambda)             (None, 4, 4, 320)    0           activation_28[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 4, 4, 40)     12800       lambda_98[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 4, 4, 40)     12800       lambda_99[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 4, 4, 40)     12800       lambda_100[0][0]
# __________________________________________________________________________________________________
# concatenate_31 (Concatenate)    (None, 4, 4, 120)    0           conv2d_85[0][0]
#                                                                  conv2d_86[0][0]
#                                                                  conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 4, 4, 120)    480         concatenate_31[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 4, 4, 120)    0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# lambda_101 (Lambda)             (None, 4, 4, 120)    0           activation_29[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_14 (DepthwiseC (None, 4, 4, 120)    1080        lambda_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 4, 4, 120)    480         depthwise_conv2d_14[0][0]
# __________________________________________________________________________________________________
# lambda_102 (Lambda)             (None, 4, 4, 40)     0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# lambda_103 (Lambda)             (None, 4, 4, 40)     0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# lambda_104 (Lambda)             (None, 4, 4, 40)     0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 4, 4, 320)    12800       lambda_102[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 4, 4, 320)    12800       lambda_103[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 4, 4, 320)    12800       lambda_104[0][0]
# __________________________________________________________________________________________________
# concatenate_32 (Concatenate)    (None, 4, 4, 960)    0           conv2d_88[0][0]
#                                                                  conv2d_89[0][0]
#                                                                  conv2d_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 4, 4, 960)    3840        concatenate_32[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 4, 4, 960)    0           activation_28[0][0]
#                                                                  batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 4, 4, 960)    0           add_11[0][0]
# __________________________________________________________________________________________________
# lambda_105 (Lambda)             (None, 4, 4, 320)    0           activation_30[0][0]
# __________________________________________________________________________________________________
# lambda_106 (Lambda)             (None, 4, 4, 320)    0           activation_30[0][0]
# __________________________________________________________________________________________________
# lambda_107 (Lambda)             (None, 4, 4, 320)    0           activation_30[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 4, 4, 40)     12800       lambda_105[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 4, 4, 40)     12800       lambda_106[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 4, 4, 40)     12800       lambda_107[0][0]
# __________________________________________________________________________________________________
# concatenate_33 (Concatenate)    (None, 4, 4, 120)    0           conv2d_91[0][0]
#                                                                  conv2d_92[0][0]
#                                                                  conv2d_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 4, 4, 120)    480         concatenate_33[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 4, 4, 120)    0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# lambda_108 (Lambda)             (None, 4, 4, 120)    0           activation_31[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_15 (DepthwiseC (None, 4, 4, 120)    1080        lambda_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 4, 4, 120)    480         depthwise_conv2d_15[0][0]
# __________________________________________________________________________________________________
# lambda_109 (Lambda)             (None, 4, 4, 40)     0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# lambda_110 (Lambda)             (None, 4, 4, 40)     0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# lambda_111 (Lambda)             (None, 4, 4, 40)     0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 4, 4, 320)    12800       lambda_109[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 4, 4, 320)    12800       lambda_110[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 4, 4, 320)    12800       lambda_111[0][0]
# __________________________________________________________________________________________________
# concatenate_34 (Concatenate)    (None, 4, 4, 960)    0           conv2d_94[0][0]
#                                                                  conv2d_95[0][0]
#                                                                  conv2d_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 4, 4, 960)    3840        concatenate_34[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 4, 4, 960)    0           activation_30[0][0]
#                                                                  batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 4, 4, 960)    0           add_12[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 960)          0           activation_32[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           9610        global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 489,898
# Trainable params: 469,738
# Non-trainable params: 20,160
# __________________________________________________________________________________________________

# %% [markdown]
# #### ShuffleNet training and evaluation.
#
# Trained for 200 epochs and achieved 80% accuracy on validaton dataset.

# %%
import time
sgd = tf.keras.optimizers.SGD(lr=0.005, decay=4e-5, momentum=0.9, nesterov=True)

# tf.keras.optimizers.Adam()
model.compile(loss='categorical_crossentropy',
                optimizer=sgd,
                metrics=['accuracy'])
reduce_lr_loss = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=7, verbose=1, epsilon=1e-4, mode='min')
start_time = time.time()
for zz in range(1,num_epochs+1):
  dataset_train = tf.data.TFRecordDataset(filename_train)#.repeat(1)
  dataset_train = dataset_train.apply(tf.data.experimental.shuffle_and_repeat(50000,1))
  dataset_train = dataset_train.apply(tf.data.experimental.map_and_batch(parser,batch_size, num_parallel_calls=batch_size))
  print("TrainEpochs number{}/{}".format(zz,num_epochs))
  
  model.fit_generator(dataset_train,steps_per_epoch=int(50000/batch_size),epochs=1,verbose=1)#, callbacks = [reduce_lr_loss])#,validation_data=dataset_test)

  print("Test Epochs number{}/{}".format(zz,num_epochs))
  model.evaluate_generator(dataset_test,steps=int(10000/batch_size),verbose=1)
  print("  ")
  print("------------------------",time.time()-start_time)
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# WARNING:tensorflow:From <ipython-input-11-ff2a42d0b7f5>:12: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# WARNING:tensorflow:From <ipython-input-11-ff2a42d0b7f5>:13: map_and_batch (from tensorflow.python.data.experimental.ops.batching) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map(map_func, num_parallel_calls)` followed by `tf.data.Dataset.batch(batch_size, drop_remainder)`. Static tf.data optimizations will take care of using the fused implementation.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.image.resize_image_with_crop_or_pad is deprecated. Please use tf.image.resize_with_crop_or_pad instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.random_crop is deprecated. Please use tf.image.random_crop instead.
#
# WARNING:tensorflow:From <ipython-input-5-479aa4c81f5c>:19: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# TrainEpochs number1/200
# 79/97 [=======================>......] - ETA: 10s - loss: 2.3783 - acc: 0.1864WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number1/200
# 19/19 [==============================] - 3s 164ms/step - loss: 2.3342 - acc: 0.0996
#
# ------------------------ 48.449668645858765
# TrainEpochs number2/200
# 79/97 [=======================>......] - ETA: 9s - loss: 2.0056 - acc: 0.2723WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number2/200
# 19/19 [==============================] - 3s 164ms/step - loss: 2.4622 - acc: 0.1264
#
# ------------------------ 92.70846056938171
# TrainEpochs number3/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.8887 - acc: 0.3088WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number3/200
# 19/19 [==============================] - 3s 161ms/step - loss: 2.7781 - acc: 0.0906
#
# ------------------------ 136.51736760139465
# TrainEpochs number4/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.7881 - acc: 0.3466WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number4/200
# 19/19 [==============================] - 3s 164ms/step - loss: 3.1547 - acc: 0.1124
#
# ------------------------ 180.2589681148529
# TrainEpochs number5/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.6822 - acc: 0.3800WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number5/200
# 19/19 [==============================] - 3s 168ms/step - loss: 3.1684 - acc: 0.1095
#
# ------------------------ 224.15447115898132
# TrainEpochs number6/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.6413 - acc: 0.3935WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number6/200
# 19/19 [==============================] - 3s 172ms/step - loss: 2.6756 - acc: 0.1844
#
# ------------------------ 268.2587676048279
# TrainEpochs number7/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.6069 - acc: 0.4127WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number7/200
# 19/19 [==============================] - 3s 166ms/step - loss: 1.7210 - acc: 0.3828
#
# ------------------------ 312.07542848587036
# TrainEpochs number8/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.5644 - acc: 0.4245WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number8/200
# 19/19 [==============================] - 3s 173ms/step - loss: 2.0334 - acc: 0.3643
#
# ------------------------ 356.33085584640503
# TrainEpochs number9/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.5288 - acc: 0.4437WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number9/200
# 19/19 [==============================] - 3s 170ms/step - loss: 1.8504 - acc: 0.3958
#
# ------------------------ 400.62270045280457
# TrainEpochs number10/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.4864 - acc: 0.4586WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number10/200
# 19/19 [==============================] - 3s 171ms/step - loss: 1.8542 - acc: 0.4089
#
# ------------------------ 445.10064482688904
# TrainEpochs number11/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.4562 - acc: 0.4685WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number11/200
# 19/19 [==============================] - 3s 167ms/step - loss: 1.7464 - acc: 0.4389
#
# ------------------------ 489.17048358917236
# TrainEpochs number12/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.4283 - acc: 0.4811WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number12/200
# 19/19 [==============================] - 3s 163ms/step - loss: 1.8468 - acc: 0.4120
#
# ------------------------ 533.2103338241577
# TrainEpochs number13/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.4204 - acc: 0.4871WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number13/200
# 19/19 [==============================] - 3s 165ms/step - loss: 1.6814 - acc: 0.4566
#
# ------------------------ 577.2037119865417
# TrainEpochs number14/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.3842 - acc: 0.5027WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number14/200
# 19/19 [==============================] - 3s 174ms/step - loss: 1.7129 - acc: 0.4575
#
# ------------------------ 621.4505171775818
# TrainEpochs number15/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.3606 - acc: 0.5078WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number15/200
# 19/19 [==============================] - 3s 167ms/step - loss: 1.5861 - acc: 0.4839
#
# ------------------------ 665.1984474658966
# TrainEpochs number16/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.3475 - acc: 0.5131WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number16/200
# 19/19 [==============================] - 3s 167ms/step - loss: 1.4745 - acc: 0.4971
#
# ------------------------ 709.2000606060028
# TrainEpochs number17/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.3292 - acc: 0.5186WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number17/200
# 19/19 [==============================] - 3s 163ms/step - loss: 1.7549 - acc: 0.4554
#
# ------------------------ 753.061363697052
# TrainEpochs number18/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.3138 - acc: 0.5247WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number18/200
# 19/19 [==============================] - 3s 157ms/step - loss: 1.9268 - acc: 0.3994
#
# ------------------------ 796.5902585983276
# TrainEpochs number19/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.2918 - acc: 0.5369WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number19/200
# 19/19 [==============================] - 3s 170ms/step - loss: 1.7774 - acc: 0.4386
#
# ------------------------ 840.625538110733
# TrainEpochs number20/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.2775 - acc: 0.5444WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number20/200
# 19/19 [==============================] - 3s 168ms/step - loss: 1.8625 - acc: 0.4561
#
# ------------------------ 884.4734029769897
# TrainEpochs number21/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.2598 - acc: 0.5472WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number21/200
# 19/19 [==============================] - 3s 165ms/step - loss: 1.4473 - acc: 0.5150
#
# ------------------------ 928.4405038356781
# TrainEpochs number22/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.2434 - acc: 0.5537WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number22/200
# 19/19 [==============================] - 3s 165ms/step - loss: 1.4424 - acc: 0.5199
#
# ------------------------ 972.1007952690125
# TrainEpochs number23/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.2245 - acc: 0.5605WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number23/200
# 19/19 [==============================] - 3s 165ms/step - loss: 1.4358 - acc: 0.4962
#
# ------------------------ 1016.0241441726685
# TrainEpochs number24/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.2156 - acc: 0.5642WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number24/200
# 19/19 [==============================] - 3s 168ms/step - loss: 1.3256 - acc: 0.5484
#
# ------------------------ 1059.9703528881073
# TrainEpochs number25/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.2036 - acc: 0.5679WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number25/200
# 19/19 [==============================] - 3s 172ms/step - loss: 1.5150 - acc: 0.4936
#
# ------------------------ 1104.0929608345032
# TrainEpochs number26/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.1872 - acc: 0.5735WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number26/200
# 19/19 [==============================] - 3s 163ms/step - loss: 1.5336 - acc: 0.5087
#
# ------------------------ 1148.2352137565613
# TrainEpochs number27/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.1775 - acc: 0.5784WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number27/200
# 19/19 [==============================] - 3s 168ms/step - loss: 1.2192 - acc: 0.5824
#
# ------------------------ 1192.4266986846924
# TrainEpochs number28/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.1702 - acc: 0.5833WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number28/200
# 19/19 [==============================] - 3s 167ms/step - loss: 1.4039 - acc: 0.5307
#
# ------------------------ 1236.5585100650787
# TrainEpochs number29/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.1565 - acc: 0.5856WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number29/200
# 19/19 [==============================] - 3s 163ms/step - loss: 1.3201 - acc: 0.5534
#
# ------------------------ 1280.7549941539764
# TrainEpochs number30/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.1420 - acc: 0.5911WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number30/200
# 19/19 [==============================] - 3s 171ms/step - loss: 1.1758 - acc: 0.6075
#
# ------------------------ 1325.077917098999
# TrainEpochs number31/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.1256 - acc: 0.5979WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number31/200
# 19/19 [==============================] - 3s 160ms/step - loss: 1.4205 - acc: 0.5382
#
# ------------------------ 1369.1881663799286
# TrainEpochs number32/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.1224 - acc: 0.6002WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number32/200
# 19/19 [==============================] - 3s 163ms/step - loss: 1.1683 - acc: 0.5973
#
# ------------------------ 1413.1960880756378
# TrainEpochs number33/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.1114 - acc: 0.6030WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number33/200
# 19/19 [==============================] - 3s 167ms/step - loss: 1.7377 - acc: 0.4623
#
# ------------------------ 1457.1400299072266
# TrainEpochs number34/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.1074 - acc: 0.6025WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number34/200
# 19/19 [==============================] - 3s 172ms/step - loss: 1.5383 - acc: 0.5048
#
# ------------------------ 1501.5414280891418
# TrainEpochs number35/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.0959 - acc: 0.6063WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number35/200
# 19/19 [==============================] - 3s 162ms/step - loss: 1.2330 - acc: 0.5845
#
# ------------------------ 1545.244086265564
# TrainEpochs number36/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.0793 - acc: 0.6166WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number36/200
# 19/19 [==============================] - 3s 166ms/step - loss: 1.1846 - acc: 0.6030
#
# ------------------------ 1589.0904643535614
# TrainEpochs number37/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.0705 - acc: 0.6176WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number37/200
# 19/19 [==============================] - 3s 175ms/step - loss: 1.1770 - acc: 0.5962
#
# ------------------------ 1633.691193819046
# TrainEpochs number38/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.0563 - acc: 0.6241WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number38/200
# 19/19 [==============================] - 3s 165ms/step - loss: 1.1748 - acc: 0.5981
#
# ------------------------ 1677.7392175197601
# TrainEpochs number39/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.0495 - acc: 0.6273WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number39/200
# 19/19 [==============================] - 3s 167ms/step - loss: 1.5239 - acc: 0.5405
#
# ------------------------ 1721.9725069999695
# TrainEpochs number40/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.0408 - acc: 0.6262WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number40/200
# 19/19 [==============================] - 3s 161ms/step - loss: 1.1253 - acc: 0.6218
#
# ------------------------ 1766.1763000488281
# TrainEpochs number41/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.0297 - acc: 0.6295WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number41/200
# 19/19 [==============================] - 3s 166ms/step - loss: 1.0846 - acc: 0.6249
#
# ------------------------ 1810.212257385254
# TrainEpochs number42/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.0256 - acc: 0.6320WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number42/200
# 19/19 [==============================] - 3s 162ms/step - loss: 1.0779 - acc: 0.6274
#
# ------------------------ 1854.0449795722961
# TrainEpochs number43/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.0263 - acc: 0.6312WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number43/200
# 19/19 [==============================] - 3s 168ms/step - loss: 1.1804 - acc: 0.5961
#
# ------------------------ 1898.1824181079865
# TrainEpochs number44/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.0078 - acc: 0.6393WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number44/200
# 19/19 [==============================] - 3s 172ms/step - loss: 1.0505 - acc: 0.6324
#
# ------------------------ 1942.3738827705383
# TrainEpochs number45/200
# 79/97 [=======================>......] - ETA: 9s - loss: 1.0026 - acc: 0.6415WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number45/200
# 19/19 [==============================] - 3s 161ms/step - loss: 1.1605 - acc: 0.6042
#
# ------------------------ 1986.297388792038
# TrainEpochs number46/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.9949 - acc: 0.6444WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number46/200
# 19/19 [==============================] - 3s 167ms/step - loss: 1.1269 - acc: 0.6172
#
# ------------------------ 2030.2029521465302
# TrainEpochs number47/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.9880 - acc: 0.6467WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number47/200
# 19/19 [==============================] - 3s 165ms/step - loss: 1.2547 - acc: 0.5862
#
# ------------------------ 2074.3409609794617
# TrainEpochs number48/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.9781 - acc: 0.6554WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number48/200
# 19/19 [==============================] - 3s 166ms/step - loss: 1.2356 - acc: 0.5889
#
# ------------------------ 2118.493467569351
# TrainEpochs number49/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.9697 - acc: 0.6564WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number49/200
# 19/19 [==============================] - 3s 167ms/step - loss: 1.3540 - acc: 0.5777
#
# ------------------------ 2162.6095910072327
# TrainEpochs number50/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.9649 - acc: 0.6556WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number50/200
# 19/19 [==============================] - 3s 169ms/step - loss: 1.0560 - acc: 0.6401
#
# ------------------------ 2207.0552365779877
# TrainEpochs number51/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.9538 - acc: 0.6613WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number51/200
# 19/19 [==============================] - 3s 167ms/step - loss: 1.0638 - acc: 0.6425
#
# ------------------------ 2250.930983543396
# TrainEpochs number52/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.9530 - acc: 0.6611WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number52/200
# 19/19 [==============================] - 3s 166ms/step - loss: 1.0583 - acc: 0.6401
#
# ------------------------ 2294.967524766922
# TrainEpochs number53/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.9440 - acc: 0.6647WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number53/200
# 19/19 [==============================] - 3s 166ms/step - loss: 1.0598 - acc: 0.6450
#
# ------------------------ 2338.9161450862885
# TrainEpochs number54/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.9317 - acc: 0.6681WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number54/200
# 19/19 [==============================] - 3s 163ms/step - loss: 1.0321 - acc: 0.6494
#
# ------------------------ 2383.123016357422
# TrainEpochs number55/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.9249 - acc: 0.6673WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number55/200
# 19/19 [==============================] - 3s 168ms/step - loss: 0.9769 - acc: 0.6688
#
# ------------------------ 2427.105007648468
# TrainEpochs number56/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.9247 - acc: 0.6688WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number56/200
# 19/19 [==============================] - 3s 167ms/step - loss: 1.0683 - acc: 0.6492
#
# ------------------------ 2471.3062613010406
# TrainEpochs number57/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.9170 - acc: 0.6771WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number57/200
# 19/19 [==============================] - 3s 162ms/step - loss: 0.9797 - acc: 0.6653
#
# ------------------------ 2515.385356903076
# TrainEpochs number58/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.9080 - acc: 0.6762WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number58/200
# 19/19 [==============================] - 3s 165ms/step - loss: 1.1081 - acc: 0.6377
#
# ------------------------ 2559.442416906357
# TrainEpochs number59/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.9060 - acc: 0.6797WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number59/200
# 19/19 [==============================] - 3s 164ms/step - loss: 1.0120 - acc: 0.6682
#
# ------------------------ 2603.487195253372
# TrainEpochs number60/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.9006 - acc: 0.6800WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number60/200
# 19/19 [==============================] - 3s 162ms/step - loss: 0.9649 - acc: 0.6634
#
# ------------------------ 2647.3084003925323
# TrainEpochs number61/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.8956 - acc: 0.6824WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number61/200
# 19/19 [==============================] - 3s 164ms/step - loss: 1.0894 - acc: 0.6436
#
# ------------------------ 2690.839718580246
# TrainEpochs number62/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.8873 - acc: 0.6870WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number62/200
# 19/19 [==============================] - 3s 164ms/step - loss: 0.8904 - acc: 0.6921
#
# ------------------------ 2734.7801101207733
# TrainEpochs number63/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.8810 - acc: 0.6880WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number63/200
# 19/19 [==============================] - 3s 162ms/step - loss: 1.1163 - acc: 0.6308
#
# ------------------------ 2778.56822180748
# TrainEpochs number64/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.8752 - acc: 0.6901WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number64/200
# 19/19 [==============================] - 3s 163ms/step - loss: 1.2265 - acc: 0.6213
#
# ------------------------ 2822.4368376731873
# TrainEpochs number65/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.8691 - acc: 0.6931WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number65/200
# 19/19 [==============================] - 3s 162ms/step - loss: 1.1000 - acc: 0.6199
#
# ------------------------ 2866.467927455902
# TrainEpochs number66/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.8680 - acc: 0.6923WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number66/200
# 19/19 [==============================] - 3s 165ms/step - loss: 0.9878 - acc: 0.6637
#
# ------------------------ 2910.700975418091
# TrainEpochs number67/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.8540 - acc: 0.6973WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number67/200
# 19/19 [==============================] - 3s 165ms/step - loss: 1.0115 - acc: 0.6702
#
# ------------------------ 2954.8333525657654
# TrainEpochs number68/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.8535 - acc: 0.6991WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number68/200
# 19/19 [==============================] - 3s 164ms/step - loss: 0.9807 - acc: 0.6692
#
# ------------------------ 2998.707129240036
# TrainEpochs number69/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.8534 - acc: 0.6973WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number69/200
# 19/19 [==============================] - 3s 163ms/step - loss: 1.0292 - acc: 0.6531
#
# ------------------------ 3042.532082080841
# TrainEpochs number70/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.8449 - acc: 0.6988WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number70/200
# 19/19 [==============================] - 3s 166ms/step - loss: 0.9290 - acc: 0.6793
#
# ------------------------ 3086.6981875896454
# TrainEpochs number71/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.8389 - acc: 0.7048WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number71/200
# 19/19 [==============================] - 3s 161ms/step - loss: 0.9919 - acc: 0.6644
#
# ------------------------ 3130.6506917476654
# TrainEpochs number72/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.8269 - acc: 0.7056WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number72/200
# 19/19 [==============================] - 3s 167ms/step - loss: 0.9108 - acc: 0.6907
#
# ------------------------ 3174.68799161911
# TrainEpochs number73/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.8269 - acc: 0.7078WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number73/200
# 19/19 [==============================] - 3s 164ms/step - loss: 0.9067 - acc: 0.6918
#
# ------------------------ 3218.6380825042725
# TrainEpochs number74/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.8270 - acc: 0.7070WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number74/200
# 19/19 [==============================] - 3s 164ms/step - loss: 0.9533 - acc: 0.6736
#
# ------------------------ 3262.5014321804047
# TrainEpochs number75/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.8216 - acc: 0.7077WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number75/200
# 19/19 [==============================] - 3s 164ms/step - loss: 0.9380 - acc: 0.6800
#
# ------------------------ 3306.3884341716766
# TrainEpochs number76/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.8102 - acc: 0.7145WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number76/200
# 19/19 [==============================] - 3s 166ms/step - loss: 0.8985 - acc: 0.6979
#
# ------------------------ 3350.2917246818542
# TrainEpochs number77/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.8006 - acc: 0.7160WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number77/200
# 19/19 [==============================] - 3s 163ms/step - loss: 0.9348 - acc: 0.6837
#
# ------------------------ 3394.1762294769287
# TrainEpochs number78/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.8038 - acc: 0.7144WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number78/200
# 19/19 [==============================] - 3s 162ms/step - loss: 1.0089 - acc: 0.6624
#
# ------------------------ 3438.1746044158936
# TrainEpochs number79/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.8067 - acc: 0.7132WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number79/200
# 19/19 [==============================] - 3s 168ms/step - loss: 1.3637 - acc: 0.5733
#
# ------------------------ 3481.9672849178314
# TrainEpochs number80/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.7943 - acc: 0.7181WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number80/200
# 19/19 [==============================] - 3s 166ms/step - loss: 0.9337 - acc: 0.6968
#
# ------------------------ 3526.2075805664062
# TrainEpochs number81/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.8033 - acc: 0.7162WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number81/200
# 19/19 [==============================] - 3s 169ms/step - loss: 1.1107 - acc: 0.6248
#
# ------------------------ 3570.359034538269
# TrainEpochs number82/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.7919 - acc: 0.7184WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number82/200
# 19/19 [==============================] - 3s 161ms/step - loss: 0.9448 - acc: 0.6971
#
# ------------------------ 3614.0561504364014
# TrainEpochs number83/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.7855 - acc: 0.7224WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number83/200
# 19/19 [==============================] - 3s 163ms/step - loss: 0.8503 - acc: 0.7104
#
# ------------------------ 3658.1048436164856
# TrainEpochs number84/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.7807 - acc: 0.7226WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number84/200
# 19/19 [==============================] - 3s 177ms/step - loss: 1.0647 - acc: 0.6515
#
# ------------------------ 3702.5055210590363
# TrainEpochs number85/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.7817 - acc: 0.7221WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number85/200
# 19/19 [==============================] - 3s 166ms/step - loss: 0.9100 - acc: 0.6914
#
# ------------------------ 3746.5649785995483
# TrainEpochs number86/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.7759 - acc: 0.7248WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number86/200
# 19/19 [==============================] - 3s 159ms/step - loss: 0.8143 - acc: 0.7164
#
# ------------------------ 3790.327380180359
# TrainEpochs number87/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.7673 - acc: 0.7300WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number87/200
# 19/19 [==============================] - 3s 162ms/step - loss: 0.8197 - acc: 0.7243
#
# ------------------------ 3834.432161808014
# TrainEpochs number88/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.7667 - acc: 0.7276WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number88/200
# 19/19 [==============================] - 3s 163ms/step - loss: 0.7911 - acc: 0.7329
#
# ------------------------ 3878.1962385177612
# TrainEpochs number89/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.7587 - acc: 0.7293WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number89/200
# 19/19 [==============================] - 3s 164ms/step - loss: 0.8702 - acc: 0.7061
#
# ------------------------ 3922.1579740047455
# TrainEpochs number90/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.7566 - acc: 0.7307WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number90/200
# 19/19 [==============================] - 3s 166ms/step - loss: 0.8400 - acc: 0.7126
#
# ------------------------ 3965.9326899051666
# TrainEpochs number91/200
# ...
#
# ------------------------ 7443.186151981354
# TrainEpochs number170/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.5792 - acc: 0.7961WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number170/200
# 19/19 [==============================] - 3s 164ms/step - loss: 0.8406 - acc: 0.7338
#
# ------------------------ 7486.965088129044
# TrainEpochs number171/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.5825 - acc: 0.7944WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number171/200
# 19/19 [==============================] - 3s 169ms/step - loss: 0.7021 - acc: 0.7618
#
# ------------------------ 7531.01513004303
# TrainEpochs number172/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.5810 - acc: 0.7964WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number172/200
# 19/19 [==============================] - 3s 167ms/step - loss: 0.7372 - acc: 0.7516
#
# ------------------------ 7574.823741197586
# TrainEpochs number173/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.5819 - acc: 0.7939WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number173/200
# 19/19 [==============================] - 3s 168ms/step - loss: 0.7737 - acc: 0.7421
#
# ------------------------ 7618.532579898834
# TrainEpochs number174/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.5703 - acc: 0.7994WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number174/200
# 19/19 [==============================] - 3s 163ms/step - loss: 0.7348 - acc: 0.7610
#
# ------------------------ 7662.530893087387
# TrainEpochs number175/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.5662 - acc: 0.7980WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number175/200
# 19/19 [==============================] - 3s 168ms/step - loss: 0.8829 - acc: 0.7251
#
# ------------------------ 7706.31733417511
# TrainEpochs number176/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.5721 - acc: 0.7993WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number176/200
# 19/19 [==============================] - 3s 165ms/step - loss: 0.7091 - acc: 0.7666
#
# ------------------------ 7750.183528184891
# TrainEpochs number177/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.5693 - acc: 0.7981WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number177/200
# 19/19 [==============================] - 3s 164ms/step - loss: 0.7736 - acc: 0.7447
#
# ------------------------ 7793.817153453827
# TrainEpochs number178/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.5684 - acc: 0.7974WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number178/200
# 19/19 [==============================] - 3s 170ms/step - loss: 0.7297 - acc: 0.7654
#
# ------------------------ 7837.820742607117
# TrainEpochs number179/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.5683 - acc: 0.7990WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number179/200
# 19/19 [==============================] - 3s 167ms/step - loss: 0.7939 - acc: 0.7421
#
# ------------------------ 7881.971159934998
# TrainEpochs number180/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.5672 - acc: 0.7990WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number180/200
# 19/19 [==============================] - 3s 166ms/step - loss: 0.6884 - acc: 0.7691
#
# ------------------------ 7925.713798284531
# TrainEpochs number181/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.5561 - acc: 0.8020WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number181/200
# 19/19 [==============================] - 3s 161ms/step - loss: 0.8664 - acc: 0.7338
#
# ------------------------ 7969.23730635643
# TrainEpochs number182/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.5661 - acc: 0.7993WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number182/200
# 19/19 [==============================] - 3s 166ms/step - loss: 0.7541 - acc: 0.7573
#
# ------------------------ 8013.239942073822
# TrainEpochs number183/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.5530 - acc: 0.8027WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number183/200
# 19/19 [==============================] - 3s 166ms/step - loss: 0.6898 - acc: 0.7696
#
# ------------------------ 8057.086543798447
# TrainEpochs number184/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.5571 - acc: 0.8013WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number184/200
# 19/19 [==============================] - 3s 166ms/step - loss: 0.6961 - acc: 0.7678
#
# ------------------------ 8100.933670043945
# TrainEpochs number185/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.5566 - acc: 0.8037WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number185/200
# 19/19 [==============================] - 3s 167ms/step - loss: 0.6992 - acc: 0.7682
#
# ------------------------ 8144.857380628586
# TrainEpochs number186/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.5549 - acc: 0.8029WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number186/200
# 19/19 [==============================] - 3s 166ms/step - loss: 0.7474 - acc: 0.7546
#
# ------------------------ 8188.7967665195465
# TrainEpochs number187/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.5551 - acc: 0.8044WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number187/200
# 19/19 [==============================] - 3s 167ms/step - loss: 0.7504 - acc: 0.7539
#
# ------------------------ 8232.584104299545
# TrainEpochs number188/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.5501 - acc: 0.8051WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number188/200
# 19/19 [==============================] - 3s 161ms/step - loss: 0.7216 - acc: 0.7608
#
# ------------------------ 8276.097117185593
# TrainEpochs number189/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.5515 - acc: 0.8040WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number189/200
# 19/19 [==============================] - 3s 164ms/step - loss: 0.7565 - acc: 0.7572
#
# ------------------------ 8320.066603899002
# TrainEpochs number190/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.5455 - acc: 0.8062WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number190/200
# 19/19 [==============================] - 3s 164ms/step - loss: 0.7534 - acc: 0.7587
#
# ------------------------ 8364.06547832489
# TrainEpochs number191/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.5520 - acc: 0.8010WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number191/200
# 19/19 [==============================] - 3s 165ms/step - loss: 0.7742 - acc: 0.7528
#
# ------------------------ 8408.025051116943
# TrainEpochs number192/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.5451 - acc: 0.8070WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number192/200
# 19/19 [==============================] - 3s 165ms/step - loss: 0.6965 - acc: 0.7713
#
# ------------------------ 8451.75177359581
# TrainEpochs number193/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.5469 - acc: 0.8055WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number193/200
# 19/19 [==============================] - 3s 164ms/step - loss: 0.7178 - acc: 0.7641
#
# ------------------------ 8495.625786781311
# TrainEpochs number194/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.5432 - acc: 0.8078WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number194/200
# 19/19 [==============================] - 3s 166ms/step - loss: 0.7967 - acc: 0.7465
#
# ------------------------ 8539.477550506592
# TrainEpochs number195/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.5420 - acc: 0.8061WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number195/200
# 19/19 [==============================] - 3s 166ms/step - loss: 0.7681 - acc: 0.7537
#
# ------------------------ 8583.221329450607
# TrainEpochs number196/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.5393 - acc: 0.8080WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number196/200
# 19/19 [==============================] - 3s 162ms/step - loss: 0.7533 - acc: 0.7572
#
# ------------------------ 8627.08334684372
# TrainEpochs number197/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.5404 - acc: 0.8074WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number197/200
# 19/19 [==============================] - 3s 164ms/step - loss: 0.6797 - acc: 0.7742
#
# ------------------------ 8671.00539278984
# TrainEpochs number198/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.5391 - acc: 0.8095WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number198/200
# 19/19 [==============================] - 3s 165ms/step - loss: 0.7831 - acc: 0.7507
#
# ------------------------ 8714.81759262085
# TrainEpochs number199/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.5333 - acc: 0.8105WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number199/200
# 19/19 [==============================] - 3s 165ms/step - loss: 0.6654 - acc: 0.7805
#
# ------------------------ 8758.52014040947
# TrainEpochs number200/200
# 79/97 [=======================>......] - ETA: 9s - loss: 0.5379 - acc: 0.8078WARNING:tensorflow:Your dataset ran out of data; interrupting training. Make sure that your dataset can generate at least `steps_per_epoch * epochs` batches (in this case, 97 batches). You may need to use the repeat() function when building your dataset.
# Test Epochs number200/200
# 19/19 [==============================] - 3s 179ms/step - loss: 0.7474 - acc: 0.7599
#
# ------------------------ 8802.479091644287

# %%
# !nvidia-smi
# Out:
# Fri Dec 13 08:58:49 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.36       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   56C    P0    40W / 250W |  15765MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Visualizing CutOut

# %%
batch_size = 5

dataset_train = tf.data.TFRecordDataset(filename_train).repeat(1)
# dataset_test = dataset_train.apply(tf.contrib.data.shuffle_and_repeat(1,40000))
# dataset_test = dataset_train.apply(tf.contrib.data.map_and_batch(parser,batch_size))
dataset_train = dataset_train.map(parser, num_parallel_calls=batch_size)
dataset_train = dataset_train.shuffle(buffer_size=40000) 
dataset_train = dataset_train.batch(batch_size)

# %%
% matplotlib inline
z=0
fig, ax = plt.subplots(3,5, figsize=(10,10))
for j,i in enumerate(dataset_train):
#     print("test",i[0].shape,i[1].shape,j)
    for l,k in enumerate(i[0]):
#         print(k.shape)
#         print(z,l)
        ax[z,l].imshow(k)
        ax[z,l].set_title("ORIGINAL")
    z += 1
    if z == 3:  
      break

# %% [markdown]
# ### Miss-Classified Images

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
# Out:
# Using TensorFlow backend.
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step

# %%
import numpy as np
import matplotlib.pyplot as plt

j,t = 0, 0
X_test_wrong = []
X_test_wrong_raw = []
for i in range(len(test_features)):
  img_data = test_features[i].astype('float32')
  img_data /= 255
  img_data = np.expand_dims(img_data, axis=0)
#   img_data = test_features[i].reshape(1, 32, 32,3)
  t += 1
#   print(model.predict(img_data)[0])
#   print(np.argmax(model.predict(img_data)[0]))
#   print(test_labels[i][0])
  if np.argmax(model.predict(img_data)[0]) != test_labels[i][0]:
    X_test_wrong.append((img_data, np.argmax(model.predict(img_data)[0]), test_labels[i][0]))
    X_test_wrong_raw.append((test_features[i], np.argmax(model.predict(img_data)[0]), test_labels[i][0]))
    j += 1
  if j >= 50:
    break
print('total false preds {} for samples {}'.format(j,t))
# Out:
# total false preds 50 for samples 215

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']

# %%
plt.figure(figsize=(35,35))
batch_size = 25
i = 0
for img in X_test_wrong:
  ax = plt.subplot(10,5,i+1)
  ax.set_title("pred: {}   actu: {}".format(class_names[img[1]], class_names[img[2]]), color='r')
  plt.imshow(np.reshape(np.uint8(255 * img[0]), (32,32,-1)), cmap=plt.cm.gray)
  i += 1
